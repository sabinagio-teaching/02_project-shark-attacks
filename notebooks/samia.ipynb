# %% [markdown]
# # PROJECT 02 :
# -----

# %% [markdown]
# ### BRIEF : data analysis of global shark attacks for a business idea
# You will initially examine the Shark Attack dataset, understanding its structure and formulating a hypothesis or several hypotheses about the data.
#  We hypothesize that shark attacks are more common in certain locations and peak during specific months.
# We define a Business Case, such as
#
# * “As a company that sells medical products, I want to identify destinations with high shark attack rates.”
# * “As a company providing supply transportation services, I want to know when and where shark attacks peak to plan the safe transport of medical supplies to hospitals.”
#
#  Throughout the project, we will use Python and the pandas library to apply at least five data cleaning techniques to handle missing values, duplicates, and formatting inconsistencies. After cleaning, we will perform basic exploratory data analysis to validate our hypotheses and extract insights.
#
# #### 📝 BUSINESS IDEA — 3 Bullet Points
#
# * Problem to Solve: Coastal hospitals and emergency response teams are not always prepared with the right medical supplies during periods of high shark-attack frequency. This business solves the problem by predicting when and where attacks are most likely, so medical supplies can be stocked in advance.
#
# * Business Concept: Use historical shark attack data to create global heatmaps and seasonal risk forecasts. Then provide pharmaceutical products (painkillers, antibiotics, blood bags, emergency kits) and transportation support to hospitals and ambulances near high-risk beaches.
#
# * Data Used to Profit: The business will analyze Country, Date/Month, Gender, Age, Fatality, and Type of Injury to identify high-risk locations, peak attack months, and most common injury types. This allows optimized supply production, targeted sales, and efficient delivery to the areas that need it most.

# %% [markdown]
# ## 🌀COLUMNS TO CLEAN :
# -----
#
# **- COUNTRY (global comparison between countries to invest in more)** @Blanca
#
#     * we just take the country column and make sure every country name is accurately named
#     * We are gonna check the column of COUNTRY and make sure every country name is correct
#     * We remove NULL COUNTRY data rows that dont have any country
#     * We need to make sure that the name of COUNTRY  is capitalized and written the same way for example :
#         United States of Amercia == USA == US
#         it has to have the same name and consistent!
#
# **- DATE ( MONTH + YEAR )** @Blanca
#
#     * split the date into day - month columns and only use month column
#     * interpret months which have shark attacks happen the most
#
# **- GENDER ( F or M )** @Cecilia
#
#     * We check unique values and make it so it is only two values F or M and deleted all rows that have other values
#     * we noticed mostly M get attacked
#     * percentages Male to Female victims
#     * We remove NULL DATE data rows that dont have a date or that the date doesnt include a month and a year
#     * We are gonna check the column of DATE and seperate it into three columns DAY + MONTH + YEAR
#     * We verify that the new YEAR column matches with the old YEAR column and keep the ones that match
#         * NEW YEAR COLUMN is the one split from the DATE column
#         * OLD YEAR COLUMN is the one already existing in the original sheet
#     * Once we finish comparing the new YEAR column vs old YEAR column and we find them not matching on some data rows. we remove the none matching ones so we keep clean data of accurate years
#     * We remove the DAY and OLD YEAR columns
#     * We are gonna keep the MONTH and matching YEAR
#
# **- AGE (victims age ranges)** @Samia
#
#     * majority of victims survive
#     * we split the age groups into three categories (minors under 18 / adults 18-40 and 40+)
#     * keep in mind complications depending on age when getting treated
#     * percentages of victims based on age ranges
#     * we split the age groups into three categories (minors under 18 / adults 18-40 and elders 40+)
#     * note that there are complications depending on age
#
# **- FATALITY ( Y or N )** @Cecilia
#     * depends on the column 'Type' of injury and if it includes death or high severity
#     * mostly survived
#     * for the pharamaceutical logistics & transportation of injured people to the hospital
#     * assumption we have a percentage of survivals highest and we use it to sell for the
#     * We check unique values and make sure it is only two values Y or N and deleted all rows that have other values
#     * assumption we have a high percentage of survivals and we use it to sell the idea to profit from selling products to hospitals
#
# **- INJURY TYPE** @Samia
#
#     * clean the type of injury by severity
#     * seperate the injury type into different severity
#     * seperate the injury type into different body parts
#     * treatment depends on type of injury and thus the supplies as well

# %% [markdown]
# ## RAW DATA
# -------

# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\sboub\Documents\GitHub\02_project-shark-attacks\data\raw.csv")
print(df)
# Out:
#                          Date    Year          Type     Country  \
# 0                 25 Aug 2023  2023.0    Unprovoked   AUSTRALIA
# 1                 21 Aug-2023  2023.0  Questionable     BAHAMAS
# 2                 07-Jun-2023  2023.0    Unprovoked     BAHAMAS
# 3                 02-Mar-2023  2023.0    Unprovoked  SEYCHELLES
# 4                 18-Feb-2023  2023.0  Questionable   ARGENTINA
# ..                        ...     ...           ...         ...
# 556                      1733  1733.0       Invalid     ICELAND
# 557                      1723  1723.0    Unprovoked      ROATAN
# 558  Late 1600s Reported 1728  1642.0       Invalid      GUINEA
# 559               Before 1824     0.0    Unprovoked   AUSTRALIA
# 560      No date, Before 1963     0.0       Invalid         USA
#
#                       State                           Location  \
# 0           New South Wales  Lighthouse Beach, Port Macquarie
# 1    New Providence   Isoad             Saunders Beach, Nassau
# 2                  Freeport                     Shark Junction
# 3            Praslin Island                                NaN
# 4                 Patagonia                    Chubut Province
# ..                      ...                                ...
# 556             Bardestrand                       Talkknefiord
# 557                     NaN                                NaN
# 558                     NaN                                NaN
# 559              Queensland                           Newstead
# 560                  Hawaii                     Portlock, Oahu
#
#            Activity                           Name  Sex    Age  \
# 0           Surfing                      Toby Begg    M     44
# 1               NaN                           male    M  20/30
# 2      Scuba diving                    Heidi Ernst    F     73
# 3        Snorkeling                       Arthur …    M      6
# 4               NaN                   Diego Barría    M     32
# ..              ...                            ...  ...    ...
# 556             NaN                            NaN  NaN    NaN
# 557             NaN                  Philip Ashton    M    NaN
# 558  Went overboard  crew member of the Nieuwstadt    M    NaN
# 559        Swimming                        Eullah     F    NaN
# 560          Diving                  Val Valentine    M    NaN
#
#                                                 Injury  Fatal Y/N       Time  \
# 0                       Severe injuries to lower limbs        NaN      10h00
# 1    Body found with shark bites. Possible drowning...        NaN    Morning
# 2                                 Calf severely bitten        NaN      13h00
# 3                                     Left foot bitten        NaN  Afternoon
# 4                                Death by misadventure        NaN        NaN
# ..                                                 ...        ...        ...
# 556  Partial hominid remains recovered from shark, ...        NaN        NaN
# 557                                    Struck on thigh        NaN        NaN
# 558                                              FATAL        NaN        NaN
# 559                                  Left calf removed        NaN        NaN
# 560  A 4.3 m [14'] shark made threat display. No in...        NaN        NaN
#
#                                          Species   \
# 0                           White shark, 3.8-4.2m
# 1                                             NaN
# 2                           Caribbean rreef shark
# 3                                     Lemon shark
# 4                                             NaN
# ..                                            ...
# 556  Shark involvement prior to death unconfirmed
# 557                                           NaN
# 558                                  Questionable
# 559                                           NaN
# 560                                       Invalid
#
#                                                 Source
# 0                      B. Myatt, & M. Michaelson, GSAF
# 1                               The Tribune, 8/21/2023
# 2                                    J. Marchand, GSAF
# 3                                  Midlibre, 3/18/2023
# 4                                  El Pais,  2/27/2023
# ..                                                 ...
# 556                                         E. Olafsen
# 557                                      C.Moore, GSAF
# 558  History of the Pyrates, by D. Defoe, Vol. 2, p.28
# 559                                     B. Myatt, GSAF
# 560                                B. Sojka & D. Lloyd
#
# [561 rows x 15 columns]

# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\sboub\Documents\GitHub\02_project-shark-attacks\data\raw.csv")
df.head(5)
# Out:
#           Date    Year          Type     Country                   State  \
# 0  25 Aug 2023  2023.0    Unprovoked   AUSTRALIA         New South Wales
# 1  21 Aug-2023  2023.0  Questionable     BAHAMAS  New Providence   Isoad
# 2  07-Jun-2023  2023.0    Unprovoked     BAHAMAS                Freeport
# 3  02-Mar-2023  2023.0    Unprovoked  SEYCHELLES          Praslin Island
# 4  18-Feb-2023  2023.0  Questionable   ARGENTINA               Patagonia
#
#                             Location      Activity          Name Sex    Age  \
# 0  Lighthouse Beach, Port Macquarie        Surfing     Toby Begg   M     44
# 1             Saunders Beach, Nassau           NaN          male   M  20/30
# 2                     Shark Junction  Scuba diving   Heidi Ernst   F     73
# 3                                NaN    Snorkeling      Arthur …   M      6
# 4                    Chubut Province           NaN  Diego Barría   M     32
#
#                                               Injury  Fatal Y/N       Time  \
# 0                     Severe injuries to lower limbs        NaN      10h00
# 1  Body found with shark bites. Possible drowning...        NaN    Morning
# 2                               Calf severely bitten        NaN      13h00
# 3                                   Left foot bitten        NaN  Afternoon
# 4                              Death by misadventure        NaN        NaN
#
#                 Species                            Source
# 0  White shark, 3.8-4.2m  B. Myatt, & M. Michaelson, GSAF
# 1                    NaN           The Tribune, 8/21/2023
# 2  Caribbean rreef shark                J. Marchand, GSAF
# 3            Lemon shark              Midlibre, 3/18/2023
# 4                    NaN              El Pais,  2/27/2023

# %%
import pandas as pd

# Load the CSV
df = pd.read_csv(r"C:\Users\sboub\Documents\GitHub\02_project-shark-attacks\data\raw.csv")

# Option 1: Display the entire DataFrame (all rows and columns)
pd.set_option('display.max_rows', None)      # Show all rows
pd.set_option('display.max_columns', None)   # Show all columns

df  # Jupyter will render the full table

# %%
df.columns
# Out:
# Index(['Date', 'Year', 'Type', 'Country', 'State', 'Location', 'Activity',
#        'Name', 'Sex', 'Age', 'Injury', 'Fatal Y/N', 'Time', 'Species ',
#        'Source'],
#       dtype='object')

# %%
df.columns.to_list()
# Out:
# ['Date',
#  'Year',
#  'Type',
#  'Country',
#  'State',
#  'Location',
#  'Activity',
#  'Name',
#  'Sex',
#  'Age',
#  'Injury',
#  'Fatal Y/N',
#  'Time',
#  'Species ',
#  'Source']

# %%
df.shape
# Out:
# (561, 15)

# %%
df['Age'].describe().round(2)
# Out:
# count     238
# unique     72
# top        17
# freq       14
# Name: Age, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 561 entries, 0 to 560
# Data columns (total 15 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       561 non-null    object
#  1   Year       560 non-null    float64
#  2   Type       557 non-null    object
#  3   Country    556 non-null    object
#  4   State      508 non-null    object
#  5   Location   503 non-null    object
#  6   Activity   433 non-null    object
#  7   Name       502 non-null    object
#  8   Sex        480 non-null    object
#  9   Age        238 non-null    object
#  10  Injury     553 non-null    object
#  11  Fatal Y/N  0 non-null      float64
#  12  Time       157 non-null    object
#  13  Species    526 non-null    object
#  14  Source     556 non-null    object
# dtypes: float64(2), object(13)
# memory usage: 65.9+ KB

# %%
df['Age'].info()
#238 non-null object
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 561 entries, 0 to 560
# Series name: Age
# Non-Null Count  Dtype
# --------------  -----
# 238 non-null    object
# dtypes: object(1)
# memory usage: 4.5+ KB

# %%
df['Age'].unique()
# Out:
# array(['44', '20/30', '73', '6', '32', '50', '11', '26', nan, '35', '62',
#        '34', '31', '33', '25', '10', '8', '18', '68', '20', '19', '27',
#        '60', 'Teen', '65', '9', '40', '39', '43', '23', '38', '63', '47',
#        '48', '42', '24', '12', '16', '14', '7', '49', '17', '52', '53',
#        '45', '36', '54', '51', '22', '28', '56', '8 or 10', '75',
#        '23 & 20', '37', '29', '21', '15', '30', '16 to 18', '67', '77',
#        'mid-20s', 'Ca. 33', '? & 19', '46', '37, 67, 35, 27,  ? & 27',
#        '21, 34,24 & 35', '34 & 19', '2 to 3 months', '13', '5', '1'],
#       dtype=object)

# %%
df['Age'].nunique()
# Out:
# 72

# %%
df['Age'].describe()
# Out:
# count     238
# unique     72
# top        17
# freq       14
# Name: Age, dtype: object

# %% [markdown]
# ## CLEAN DATA
# -------

# %% [markdown]
# ### IMPORT UTILS and INIT from SRC

# %%
import sys, os
sys.path.append(os.path.abspath(".."))
from src import utils
from src import init

# %%
df['Age'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 561 entries, 0 to 560
# Series name: Age
# Non-Null Count  Dtype
# --------------  -----
# 238 non-null    object
# dtypes: object(1)
# memory usage: 4.5+ KB

# %%
df['Age'].describe()
# Out:
# count     238
# unique     72
# top        17
# freq       14
# Name: Age, dtype: object

# %%
df['Age'].unique()
# Out:
# array(['44', '20/30', '73', '6', '32', '50', '11', '26', nan, '35', '62',
#        '34', '31', '33', '25', '10', '8', '18', '68', '20', '19', '27',
#        '60', 'Teen', '65', '9', '40', '39', '43', '23', '38', '63', '47',
#        '48', '42', '24', '12', '16', '14', '7', '49', '17', '52', '53',
#        '45', '36', '54', '51', '22', '28', '56', '8 or 10', '75',
#        '23 & 20', '37', '29', '21', '15', '30', '16 to 18', '67', '77',
#        'mid-20s', 'Ca. 33', '? & 19', '46', '37, 67, 35, 27,  ? & 27',
#        '21, 34,24 & 35', '34 & 19', '2 to 3 months', '13', '5', '1'],
#       dtype=object)

# %%
df['Age'].nunique()
# Out:
# 72

# %%
import pandas as pd
import numpy as np
import re

# Load CSV
df = pd.read_csv(r"C:\Users\sboub\Documents\GitHub\02_project-shark-attacks\data\raw.csv")

def clean_age(value):
    if pd.isna(value):
        return np.nan
    
    value = str(value).strip().lower()

    # Remove common unwanted characters
    value = value.replace("years", "").replace("ca.", "").replace("about", "").strip()

    # Words that indicate no age
    if value in ["n/a", "na", "none", "?", "", "unknown"]:
        return np.nan

    # Teen keyword (assume average age 15)
    if "teen" in value:
        return 15

    # mid-20s -> 25
    if "mid" in value and "20" in value:
        return 25

    # Capture numbers if present
    nums = re.findall(r"\d+", value)

    if len(nums) == 1:
        return int(nums[0])
    
    # If multiple numbers like "20/30", "24 & 35", "16 to 18", take the average
    if len(nums) >= 2:
        nums = [int(n) for n in nums]
        return sum(nums) / len(nums)

    return np.nan

# Apply cleaning function
df['Age_clean'] = df['Age'].apply(clean_age)

# Convert to numeric properly
df['Age_clean'] = pd.to_numeric(df['Age_clean'], errors='coerce')

# Fill missing values with median
median_age = df['Age_clean'].median()
df['Age_clean'].fillna(median_age, inplace=True)

# Confirm results
print(df['Age_clean'].head(20))
print("Median age used:", median_age)

# (Optional) Save cleaned file
df.to_csv(r"C:\Users\sboub\Documents\GitHub\02_project-shark-attacks\data\cleaned.csv", index=False)
# Out:
# 0     44.0
# 1     25.0
# 2     73.0
# 3      6.0
# 4     32.0
# 5     50.0
# 6     11.0
# 7     26.0
# 8     26.0
# 9     26.0
# 10    26.0
# 11    26.0
# 12    35.0
# 13    26.0
# 14    26.0
# 15    50.0
# 16    26.0
# 17    62.0
# 18    34.0
# 19    31.0
# Name: Age_clean, dtype: float64
# Median age used: 26.0
# C:\Users\sboub\AppData\Local\Temp\ipykernel_11944\2297543679.py:50: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Age_clean'].fillna(median_age, inplace=True)

# %% [markdown]
# -----
# ### AGE CLEANED

# %%
import pandas as pd
import numpy as np
import re

# Load CSV
df = pd.read_csv(r"C:\Users\sboub\Documents\GitHub\02_project-shark-attacks\data\raw.csv")
# def Function : clean_age(value=age)
def clean_age(value):
    if pd.isna(value):
        return np.nan
    
    value = str(value).strip().lower()

    # Remove useless text
    value = value.replace("years", "").replace("year", "").replace("ca.", "").replace("about", "").strip()

    # Words meaning no age
    if value in ["n/a", "na", "none", "?", "", "unknown"]:
        return np.nan

    # Teen keyword (approx.)
    if "teen" in value:
        return 15

    # mid-20s → 25
    if "mid" in value and "20" in value:
        return 25

    # Extract numbers
    nums = re.findall(r"\d+", value)

    # Single number
    if len(nums) == 1:
        return int(nums[0])
    
    # Multiple numbers -> average them (20/30, 23 & 20, 16 to 18)
    if len(nums) >= 2:
        nums = [int(n) for n in nums]
        return sum(nums) / len(nums)

    return np.nan

# Apply cleaner
df['Age_clean'] = df['Age'].apply(clean_age)

# Convert to numeric
df['Age_clean'] = pd.to_numeric(df['Age_clean'], errors='coerce')

# Fill missing with median
median_age = df['Age_clean'].median()
df['Age_clean'].fillna(median_age, inplace=True)

# Convert to integer (no floats)
df['Age_clean'] = df['Age_clean'].round().astype(int)

# Show result
print(df[['Age', 'Age_clean']].head(20))
print("Median age used:", median_age)

# Save cleaned dataset
df.to_csv(r"C:\Users\sboub\Documents\GitHub\02_project-shark-attacks\data\cleaned.csv", index=False)

# Check result
print("\n",df["Age_clean"].value_counts())
# Out:
#       Age  Age_clean
# 0      44         44
# 1   20/30         25
# 2      73         73
# 3       6          6
# 4      32         32
# 5      50         50
# 6      11         11
# 7      26         26
# 8     NaN         26
# 9     NaN         26
# 10    NaN         26
# 11    NaN         26
# 12     35         35
# 13    NaN         26
# 14    NaN         26
# 15     50         50
# 16    NaN         26
# 17     62         62
# 18     34         34
# 19     31         31
# Median age used: 26.0
#
#  Age_clean
# 26    328
# 17     15
# 20      9
# 43      8
# 25      8
#      ...
# 67      1
# 46      1
# 2       1
# 5       1
# 1       1
# Name: count, Length: 61, dtype: int64
# C:\Users\sboub\AppData\Local\Temp\ipykernel_11944\2751151800.py:51: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Age_clean'].fillna(median_age, inplace=True)

# %%
percentiles = df['Age_clean'].describe(percentiles=[0.25, 0.5, 0.75])

print("Age Percentile Statistics:")
print(f"Min:   {int(percentiles['min'])}")
print(f"25%:   {int(percentiles['25%'])}")
print(f"50% (Median): {int(percentiles['50%'])}")
print(f"75%:   {int(percentiles['75%'])}")
print(f"Max:   {int(percentiles['max'])}")

# the majority were people up to 26 years old
# Out:
# Age Percentile Statistics:
# Min:   1
# 25%:   26
# 50% (Median): 26
# 75%:   26
# Max:   77

# %%
# Replace the original Age column with the cleaned integer values
df['Age'] = df['Age_clean']

# Optionally, drop the temporary Age_clean column
df.drop(columns=['Age_clean'], inplace=True)

# Check the result
print(df['Age'].head())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\sboub\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Age_clean'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[46], line 2
#       1 # Replace the original Age column with the cleaned integer values
# ----> 2 df['Age'] = df['Age_clean']
#       4 # Optionally, drop the temporary Age_clean column
#       5 df.drop(columns=['Age_clean'], inplace=True)
#
# File c:\Users\sboub\anaconda3\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File c:\Users\sboub\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'Age_clean'

# %%
df.head(30)
# Out:
#                     Date    Year               Type           Country  \
# 0            25 Aug 2023  2023.0            Unknown         AUSTRALIA
# 1            21 Aug-2023  2023.0            Unknown           BAHAMAS
# 2            07-Jun-2023  2023.0            Unknown           BAHAMAS
# 3            02-Mar-2023  2023.0            Unknown        SEYCHELLES
# 4            18-Feb-2023  2023.0            Unknown         ARGENTINA
# 5            08-Feb-2022  2022.0            Unknown        COSTA RICA
# 6            15-Nov-2021  2021.0            Unknown            BRAZIL
# 7            16-Oct-2021  2021.0  Missing / Unknown         AUSTRALIA
# 8            10-Sep-2021  2021.0            Unknown             EGYPT
# 9            29-Jul-2020  2020.0          No injury         AUSTRALIA
# 10           06-Jun-2020  2020.0            Unknown         AUSTRALIA
# 11           20-Dec-2019  2019.0  Provoked incident         AUSTRALIA
# 12           21-Oct-2019  2019.0            Unknown  FRENCH POLYNESIA
# 13           28-Jul-2019  2019.0            Unknown         AUSTRALIA
# 14           18-Jul-2019  2019.0            Unknown               USA
# 15           17-Jun-2019  2019.0            Unknown           BAHAMAS
# 16  Reported 16-Jul-2018  2018.0            Unknown               USA
# 17           15-Jul-2018  2018.0            Unknown          COLOMBIA
# 18           15-Apr-2018  2018.0            Unknown            BRAZIL
# 19           01-Oct-2017  2017.0            Unknown      SOUTH AFRICA
# 20           24-Sep-2017  2017.0            Unknown               USA
# 21           15-Sep-2017  2017.0            Unknown      SOUTH AFRICA
# 22           26-Aug-2017  2017.0            Unknown             SPAIN
# 23           29-Jul-2017  2017.0            Unknown               USA
# 24           20-Jul-2017  2017.0            Unknown               USA
# 25           02-Jul-2017  2017.0            Unknown           COMOROS
# 26           29-Jun-2017  2017.0            Unknown               USA
# 27           03-May-2017  2017.0            Unknown               USA
# 28           26-Apr-2017  2017.0            Unknown               USA
# 29           20-Apr-2017  2017.0            Unknown               USA
#
#                                      State  \
# 0                          New South Wales
# 1                   New Providence   Isoad
# 2                                 Freeport
# 3                           Praslin Island
# 4                                Patagonia
# 5                               Guanacoste
# 6                               São Paulo.
# 7                               Queensland
# 8                                      NaN
# 9                                 Tasmania
# 10                       Western Australia
# 11                         New South Wales
# 12                                  Moorea
# 13                              Queensland
# 14                                 Florida
# 15                                     NaN
# 16                                   Texas
# 17  San Andres and Providencia Archipelago
# 18                              Pernambuco
# 19                   Western Cape Province
# 20                                New York
# 21                   Western Cape Province
# 22                               Castellón
# 23                          South Carolina
# 24                          South Carolina
# 25                                 Anjouan
# 26                          South Carolina
# 27                              California
# 28                                 Florida
# 29                          South Carolina
#
#                                Location      Activity  \
# 0     Lighthouse Beach, Port Macquarie        Surfing
# 1                Saunders Beach, Nassau           NaN
# 2                        Shark Junction  Scuba diving
# 3                                   NaN    Snorkeling
# 4                       Chubut Province           NaN
# 5                        Playa Del Coco        Diving
# 6                       Boqueirão Beach       Playing
# 7                        Sudbury Island  Spearfishing
# 8                    Sidi Abdel Rahmen       Swimming
# 9                          Tenth Island   Sightseeing
# 10            Tantabitti Beach, Nigaloo           NaN
# 11                         Shellharbour       Fishing
# 12                          Opunohu Bay    Snorkeling
# 13                          Magra Islet    Snorkeling
# 14    Haulover Inlet, Miami-Dade County        Diving
# 15                            Wells Cay    Snorkeling
# 16                            Galveston       Surfing
# 17                            Provencia       Fishing
# 18                              Piedade      Swimming
# 19                          Dyer Island  Scuba Diving
# 20                             Rockaway       Surfing
# 21                              Hawston  Scuba Diving
# 22                      Grao de Moncofa      Swimming
# 23  Hilton Head Island, Beaufort County      Swimming
# 24  Hilton Head Island, Beaufort County      Swimming
# 25                                 Moya       Fishing
# 26                   Wrightsville Beach       Fishing
# 27          Sunset Beach, Orange County       Surfing
# 28                                  NaN   Photo shoot
# 29                    Georgetown County      Swimming
#
#                                              Name  Sex  Age  \
# 0                                       Toby Begg    M   44
# 1                                            male    M   25
# 2                                     Heidi Ernst    F   73
# 3                                        Arthur …    M    6
# 4                                    Diego Barría    M   32
# 5                                          female    F   50
# 6                                            male    M   11
# 7                                  Torrance Sambo    M   26
# 8                                         Mohamed    M   26
# 9   5.5 m runabout. Occupants: Sean & James Vinar  NaN   26
# 10                                         female    F   26
# 11                                            NaN  NaN   26
# 12                                   Emmanuelle B    F   35
# 13                                         female    F   26
# 14                                            NaN  NaN   26
# 15                                  Salvador Ritz    M   50
# 16                                     Laura Dean    F   26
# 17                         Fidelino Gómez Bernard    M   62
# 18                                  Pablo de Melo    M   34
# 19                                   Bradley Fick    M   31
# 20                                 Michah Behrend    M   33
# 21                                     Wayon Love    M   25
# 22                                         female    F   11
# 23                             Johnny Simatacolos    M   10
# 24                                   Ellie Rogier    F    8
# 25                                            NaN  NaN   26
# 26                                           male    M   26
# 27                                    Sophia Raab    F   18
# 28                                  Molly Cavelli    F   26
# 29                                           male    M   26
#
#                                                Injury  Fatal Y/N       Time  \
# 0                      Severe injuries to lower limbs        NaN      10h00
# 1   Body found with shark bites. Possible drowning...        NaN    Morning
# 2                                Calf severely bitten        NaN      13h00
# 3                                    Left foot bitten        NaN  Afternoon
# 4                               Death by misadventure        NaN        NaN
# 5                 Right forearm and left hand injured        NaN        NaN
# 6                            Minor cuts to left thigh        NaN      12h00
# 7                                         Disappeared        NaN        NaN
# 8            Laceration to arm caused by metal object        NaN        NaN
# 9   No injury to occupants, injury to shark attemp...        NaN      09h08
# 10                                                NaN        NaN        NaN
# 11                                  PROVOKED INCIDENT        NaN        NaN
# 12                  Severe injuries to arms and chest        NaN      11h30
# 13                           Lacerations to lower leg        NaN      18h30
# 14                              Unknown / Unconfirmed        NaN        NaN
# 15                         Injuries to left lower leg        NaN        NaN
# 16  Single laceration to right thigh inconsistent ...        NaN      18h00
# 17  Autopsy confirmed death by drowning, shark bit...        NaN        NaN
# 18  Multiple severe injuries to arms and leg, leg ...        NaN        NaN
# 19      FATAL, but death was probably due to drowning        NaN        NaN
# 20             Lacerations to right ankle, foot & toe        NaN      15h30
# 21      FATAL, but death was probably due to drowning        NaN  Afternoon
# 22                           Lacerations to left foot        NaN     Midday
# 23                 Abrasions and cuts to sole of foot        NaN      15h00
# 24                                       Foot injured        NaN        NaN
# 25  Skull found in shark, a probable drowning & sc...        NaN        NaN
# 26                Arm injured by hook, not by a shark        NaN      19h30
# 27  Laceration to thigh, likely caused by surfboar...        NaN      14h30
# 28                   Alleged laceration to left ankle        NaN        NaN
# 29          Laceration & puncture wounds to left foot        NaN      08h50
#
#                                           Species   \
# 0                            White shark, 3.8-4.2m
# 1                                              NaN
# 2                            Caribbean rreef shark
# 3                                      Lemon shark
# 4                                              NaN
# 5                                   Bull shark, 3m
# 6                                          dogfish
# 7                                              NaN
# 8                            No shark invovlement
# 9                                  White shark, 4m
# 10                                             NaN
# 11                                     White shark
# 12                          Oceanic whitetip shark
# 13                                             NaN
# 14                                             NaN
# 15                                             NaN
# 16                                             NaN
# 17                                             NaN
# 18                                             NaN
# 19                                             NaN
# 20                                    Questionable
# 21                                             NaN
# 22                  Shark involvement questionable
# 23                                   A small shark
# 24                 Shark involvement not confirmed
# 25  Shark involvement prior to death not confirmed
# 26                           No shark invovlement
# 27               Shark involvement highly doubtful
# 28  No shark invovlement - it ws a publicity stunt
# 29                 Shark involvement not confirmed
#
#                                         Source
# 0              B. Myatt, & M. Michaelson, GSAF
# 1                       The Tribune, 8/21/2023
# 2                            J. Marchand, GSAF
# 3                          Midlibre, 3/18/2023
# 4                          El Pais,  2/27/2023
# 5         Diario Extra Del Costa Rica 2/9/2022
# 6              K. McMurray, TrackingSharks.com
# 7              K. McMurray, TrackingSharks.com
# 8                      Dr. M. Fouda & M. Salrm
# 9                               C. Black, GSAF
# 10  B. Myatt & K. McMurray, TrackingSharks.com
# 11                              B. Myatt, GSAF
# 12            E. Clua, S. DeMarchi  & C. Meyer
# 13                               B.Myatt, GSAF
# 14                             ABC, 07/18/2019
# 15          S. Florida Sun Sentinel, 7/15/2019
# 16                    Click2Houston, 7/16/2018
# 17                              A. Velez, GSAF
# 18                            Globo, 4/16/2018
# 19                     All Africa, 10/11/2017
# 20                   S. Curatolo-Wageman, GSAF
# 21                        Ground Up, 9/20/2017
# 22        El Periodico Mediterraneo, 8/27/2017
# 23                           C. Creswell, GSAF
# 24                           C. Creswell, GSAF
# 25                             Linfo, 7/3/2017
# 26                           C. Creswell, GSAF
# 27                            R. Collier, GSAF
# 28                           The Sun, 5/6/2017
# 29                           C. Creswell, GSAF

# %% [markdown]
# -----
# ### INJURY TYPE & FATALITY DEPENDS ON THE INJURY TYPE

# %%
import pandas as pd
import numpy as np

def classify_injury(injury, fatal):
    if pd.isna(injury):
        injury = ""
    injury = injury.lower()
    fatal = str(fatal).strip().upper()

    # HOAX / FALSE
    if "hoax" in injury or "false" in injury:
        return "Hoax / False report"

    # NOT A SHARK
    if any(x in injury for x in ["not a shark", "stingray", "barracuda", "propeller", "fish"]):
        return "Not a shark"

    # NO INJURY
    if "no injury" in injury or "no injuries" in injury:
        return "No injury"

    # PROVOKED
    if "provoked" in injury:
        return "Provoked incident"

    # MISSING
    if any(x in injury for x in ["missing", "disappeared", "body not recovered"]):
        return "Missing / Unknown"

    # FATAL CASES
    if fatal == "Y":
        # drowned then bitten after death
        if "post-mortem" in injury or ("drown" in injury and "post" in injury):
            return "Fatal | Drowned, shark scavenged"
        if "unconfirmed" in injury or "probable" in injury:
            return "Fatal | Unconfirmed shark involvement"
        return "Fatal | Shark confirmed"

    # NON-FATAL CASES
    if fatal == "N":
        if any(x in injury for x in ["bitten", "lacerat", "puncture", "wound", "abrasion"]):
            return "Non-fatal | Confirmed shark bite"
        # Text but no bite
        return "Non-fatal | Other"

    # Unknown
    return "Unknown"

# Apply to dataframe
df["Type"] = df.apply(lambda row: classify_injury(row["Injury"], row["Fatal Y/N"]), axis=1)


# Check RESULTS--------------------------------------------------------------------------------------------------------------

# Count number of records in each injury type
counts = df["Type"].value_counts()

# Calculate percentages
percentages = (counts / len(df)) * 100

# Create summary DataFrame
summary = pd.DataFrame({
    "Cases": counts,
    "Percentage": percentages.round(2)
})

# Save summary to CSV
summary.to_csv("injury_type_summary.csv", index=True)

# Print SUMMARY
# print(summary)

print("Injury Type Summary:\n")
for category in counts.index:
    print(f"{category}: {counts[category]} cases  ({percentages[category]:.2f}%)")
# Out:
# Injury Type Summary:
#
# Unknown: 399 cases  (71.12%)
# No injury: 87 cases  (15.51%)
# Missing / Unknown: 38 cases  (6.77%)
# Not a shark: 27 cases  (4.81%)
# Provoked incident: 5 cases  (0.89%)
# Hoax / False report: 5 cases  (0.89%)

# %%
df.head(5)
# Out:
#           Date    Year     Type     Country                   State  \
# 0  25 Aug 2023  2023.0  Unknown   AUSTRALIA         New South Wales
# 1  21 Aug-2023  2023.0  Unknown     BAHAMAS  New Providence   Isoad
# 2  07-Jun-2023  2023.0  Unknown     BAHAMAS                Freeport
# 3  02-Mar-2023  2023.0  Unknown  SEYCHELLES          Praslin Island
# 4  18-Feb-2023  2023.0  Unknown   ARGENTINA               Patagonia
#
#                             Location      Activity          Name Sex  Age  \
# 0  Lighthouse Beach, Port Macquarie        Surfing     Toby Begg   M   44
# 1             Saunders Beach, Nassau           NaN          male   M   25
# 2                     Shark Junction  Scuba diving   Heidi Ernst   F   73
# 3                                NaN    Snorkeling      Arthur …   M    6
# 4                    Chubut Province           NaN  Diego Barría   M   32
#
#                                               Injury  Fatal Y/N       Time  \
# 0                     Severe injuries to lower limbs        NaN      10h00
# 1  Body found with shark bites. Possible drowning...        NaN    Morning
# 2                               Calf severely bitten        NaN      13h00
# 3                                   Left foot bitten        NaN  Afternoon
# 4                              Death by misadventure        NaN        NaN
#
#                 Species                            Source
# 0  White shark, 3.8-4.2m  B. Myatt, & M. Michaelson, GSAF
# 1                    NaN           The Tribune, 8/21/2023
# 2  Caribbean rreef shark                J. Marchand, GSAF
# 3            Lemon shark              Midlibre, 3/18/2023
# 4                    NaN              El Pais,  2/27/2023

# %%
import re

# Function to classify injury severity
def classify_severity(val):
    if pd.isna(val):
        val = ""
    val = val.lower()
    
    if re.search(r'fatal|death|died|deceased', val):
        return "Death"
    if re.search(r'amputation|severed|severely bitten', val):
        return "Severe injury"
    if re.search(r'bitten|bite|laceration|cuts|fracture', val):
        return "Minor injury"
    if re.search(r'no injury|not injured|unharmed', val):
        return "No injury"
    if re.search(r'possible drowning|unknown', val):
        return "Uncertain"
    
    return "Other/Unknown"

# Apply to create Injury_Severity column
df["Injury_Severity"] = df["Injury"].apply(classify_severity)

# Now derive Fatal Y/N based on Injury_Severity
def derive_fatal(severity):
    if severity == "Death":
        return "Y"
    elif severity in ["Severe injury", "Injury", "No injury", "Uncertain", "Other/Unknown"]:
        return "N"
    return "N"

df["Fatal Y/N"] = df["Injury_Severity"].apply(derive_fatal)

# Check the first rows
print(df[["Injury", "Injury_Severity", "Fatal Y/N"]].head(20))
# Out:
#                                                Injury Injury_Severity  \
# 0                      Severe injuries to lower limbs   Other/Unknown
# 1   Body found with shark bites. Possible drowning...           Death
# 2                                Calf severely bitten   Severe injury
# 3                                    Left foot bitten    Minor injury
# 4                               Death by misadventure           Death
# 5                 Right forearm and left hand injured   Other/Unknown
# 6                            Minor cuts to left thigh    Minor injury
# 7                                         Disappeared   Other/Unknown
# 8            Laceration to arm caused by metal object    Minor injury
# 9   No injury to occupants, injury to shark attemp...       No injury
# 10                                                NaN   Other/Unknown
# 11                                  PROVOKED INCIDENT   Other/Unknown
# 12                  Severe injuries to arms and chest   Other/Unknown
# 13                           Lacerations to lower leg    Minor injury
# 14                              Unknown / Unconfirmed       Uncertain
# 15                         Injuries to left lower leg   Other/Unknown
# 16  Single laceration to right thigh inconsistent ...    Minor injury
# 17  Autopsy confirmed death by drowning, shark bit...           Death
# 18  Multiple severe injuries to arms and leg, leg ...   Other/Unknown
# 19      FATAL, but death was probably due to drowning           Death
#
#    Fatal Y/N
# 0          N
# 1          Y
# 2          N
# 3          N
# 4          Y
# 5          N
# 6          N
# 7          N
# 8          N
# 9          N
# 10         N
# 11         N
# 12         N
# 13         N
# 14         N
# 15         N
# 16         N
# 17         Y
# 18         N
# 19         Y

# %%
df.tail(20)
# Out:
#                          Date    Year               Type    Country  \
# 541               27-Jan-1849  1849.0            Unknown  AUSTRALIA
# 542      Reported 17-Jul-1848  1848.0            Unknown        USA
# 543                      1847  1847.0  Missing / Unknown        USA
# 544               17-Nov-1839  1839.0            Unknown  AUSTRALIA
# 545                  Ca. 1837  1837.0            Unknown        USA
# 546              1836.07.26.R  1836.0            Unknown      SPAIN
# 547     Reported 22- Jan-1831  1831.0            Unknown  AUSTRALIA
# 548      Reported 15-Aug-1826  1826.0            Unknown    ENGLAND
# 549      Reported 30-Dec-1823  1823.0            Unknown    JAMAICA
# 550      Reported 08-Jul-1819  1819.0          No injury      SPAIN
# 551      Reported 22-May-1818  1818.0            Unknown     NORWAY
# 552      Reported 01-May-1808  1808.0            Unknown    ANTIGUA
# 553               Aug-24-1806  1896.0            Unknown        USA
# 554                  Sep-1805  1805.0            Unknown        USA
# 555                      1767  1767.0            Unknown     FRANCE
# 556                      1733  1733.0            Unknown    ICELAND
# 557                      1723  1723.0            Unknown     ROATAN
# 558  Late 1600s Reported 1728  1642.0            Unknown     GUINEA
# 559               Before 1824     0.0            Unknown  AUSTRALIA
# 560      No date, Before 1963     0.0          No injury        USA
#
#                State                              Location  \
# 541  New South Wales                                Sydney
# 542    Massachusetts                              Cape Cod
# 543   South Carolina  Charleston Harbor, Charleston County
# 544  New South Wales                                   NaN
# 545   South Carolina                      “Southern Wharf”
# 546              NaN                                   NaN
# 547         Tasmania                                Hobart
# 548       Cumberland                            Whitehaven
# 549              NaN                                   NaN
# 550              NaN                                 Cadiz
# 551              NaN                                 Herøy
# 552              NaN                      Falmouth Harbour
# 553              NaN                                   NaN
# 554         New York            Sag Harbor, Suffolk County
# 555     Côte d'Azur                             St. Tropez
# 556      Bardestrand                          Talkknefiord
# 557              NaN                                   NaN
# 558              NaN                                   NaN
# 559       Queensland                              Newstead
# 560           Hawaii                        Portlock, Oahu
#
#                             Activity                           Name  Sex  Age  \
# 541                    boat capsized          William Henry Elliott    M   26
# 542                              NaN                           male    M   26
# 543                         Swimming                 a young sailor    M   26
# 544                              NaN              Mr.Johnson (male)    M   26
# 545                              NaN           adult male, a sailor    M   26
# 546                              NaN                            NaN  NaN   26
# 547  Boat capsized, clinging to line                  Robert Dudlow    M   26
# 548                          Bathing                          child  NaN   26
# 549                              NaN                           male  NaN   26
# 550                              NaN                           male    M   26
# 551                              NaN                           male    M   26
# 552                              NaN                            NaN  NaN   26
# 553                              NaN      Crew of the schooner Mary    M   26
# 554                              NaN                            NaN    M   26
# 555                          Bathing                Samuel Matthews    M   26
# 556                              NaN                            NaN  NaN   26
# 557                              NaN                  Philip Ashton    M   26
# 558                   Went overboard  crew member of the Nieuwstadt    M   26
# 559                         Swimming                        Eullah     F   26
# 560                           Diving                  Val Valentine    M   26
#
#                                                 Injury Fatal Y/N Time  \
# 541          Torso bitten but may have been postmortem         N  NaN
# 542           Human remains recovered from 4.9 m shark         N  NaN
# 543  Disappeared, thought to have been taken by a s...         N  NaN
# 544  "Drowned, 2 days later his head was bitten off...         N  NaN
# 545   7.6 m [25'] shark caught contained human remains         N  NaN
# 546              Shark caught, contained human remains         N  NaN
# 547                      Drowned, no shark involvement         N  NaN
# 548                                              FATAL         Y  NaN
# 549                       Human remains found in shark         N  NaN
# 550                              No injury / No attack         N  NaN
# 551                                 Probable drowning          N  NaN
# 552                     Probable drowning & scavenging         N  NaN
# 553                Shark scavenged on the dead sailors         N  NaN
# 554          human remains (male) found in shark’s gut         N  NaN
# 555                           Lacerations to arm & leg         N  NaN
# 556  Partial hominid remains recovered from shark, ...         N  NaN
# 557                                    Struck on thigh         N  NaN
# 558                                              FATAL         Y  NaN
# 559                                  Left calf removed         N  NaN
# 560  A 4.3 m [14'] shark made threat display. No in...         N  NaN
#
#                                          Species   \
# 541  Shark involvement prior to death unconfirmed
# 542  Shark involvement prior to death unconfirmed
# 543  Shark involvement prior to death unconfirmed
# 544                                           NaN
# 545  Shark involvement prior to death unconfirmed
# 546  Shark involvement prior to death unconfirmed
# 547                                       Invalid
# 548                                           NaN
# 549  Shark involvement prior to death unconfirmed
# 550                                       Invalid
# 551  Shark involvement prior to death unconfirmed
# 552                                           NaN
# 553                                           NaN
# 554  Shark involvement prior to death unconfirmed
# 555       Description of shark does not ring true
# 556  Shark involvement prior to death unconfirmed
# 557                                           NaN
# 558                                  Questionable
# 559                                           NaN
# 560                                       Invalid
#
#                                                 Source Injury_Severity
# 541                         Maitland Mercury, 2/3/1849    Minor injury
# 542                    New Orleans Crescent, 7/17/1858   Other/Unknown
# 543                              W.H. Gregg, pp. 21-22   Other/Unknown
# 544                              H.D. Baldridge, p.146    Minor injury
# 545                                        W. H. Gregg   Other/Unknown
# 546                                     C. Moore, GSAF   Other/Unknown
# 547          C. Black, GSAF; Sydney Gazette, 1/22/1831   Other/Unknown
# 548                      The Times (London), 8/15/1826           Death
# 549                                                NaN   Other/Unknown
# 550                                     C. Moore, GSAF       No injury
# 551                                     C. Moore, GSAF   Other/Unknown
# 552                          London Observer, 5/1/1808   Other/Unknown
# 553                             Evening Post, 9/6/1806   Other/Unknown
# 554                               S.L. Mitchill (1814)   Other/Unknown
# 555                                                NaN    Minor injury
# 556                                         E. Olafsen   Other/Unknown
# 557                                      C.Moore, GSAF   Other/Unknown
# 558  History of the Pyrates, by D. Defoe, Vol. 2, p.28           Death
# 559                                     B. Myatt, GSAF   Other/Unknown
# 560                                B. Sojka & D. Lloyd       No injury

# %%
df['Fatal Y/N'].describe()
# Out:
# count     561
# unique      2
# top         N
# freq      450
# Name: Fatal Y/N, dtype: object

# %%
df['Age'].describe().round().astype(int)
# Out:
# count    561
# mean      27
# std       10
# min        1
# 25%       26
# 50%       26
# 75%       26
# max       77
# Name: Age, dtype: int64

# %%
df.columns
# Out:
# Index(['Date', 'Year', 'Type', 'Country', 'State', 'Location', 'Activity',
#        'Name', 'Sex', 'Age', 'Injury', 'Fatal Y/N', 'Time', 'Species ',
#        'Source', 'Injury_Severity'],
#       dtype='object')

# %%
df['Type'].describe().round()
# Out:
# count         561
# unique          6
# top       Unknown
# freq          399
# Name: Type, dtype: object
